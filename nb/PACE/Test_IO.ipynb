# %% [markdown]
# # Testing PACE I/O

# %%
import os

#from holoviews.streams import Tap
from matplotlib import animation
from matplotlib.colors import ListedColormap
#from PIL import Image, ImageEnhance
from scipy.ndimage import gaussian_filter1d
from xarray.backends.api import open_datatree
import cartopy.crs as ccrs
#import cmocean
#import earthaccess
import holoviews as hv
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
import numpy as np
#import panel.widgets as pnw
import xarray

# %% [markdown]
# # Load up a file

# %%
os.environ['OS
dfile = os.path.join(os.getenv('OS_COLOR'), 'data', 'PACE', 'early',
                     'PACE_OCI.20240413T175656.L2.OC_AOP.V1_0_0.NRT.nc')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dfile = os.path.join(os.getenv('OS_COLOR'), 'data', 'PACE', 'early',
#       2                      'PACE_OCI.20240413T175656.L2.OC_AOP.V1_0_0.NRT.nc')
#
# File <frozen posixpath>:76, in join(a, *p)
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType

# %%
datatree = open_datatree(dfile)
ds = xarray.merge(datatree.to_dict().values())
ds
# Out:
# <xarray.Dataset> Size: 3GB
# Dimensions:        (number_of_bands: 286, number_of_reflective_bands: 286,
#                     wavelength_3d: 184, number_of_lines: 1710,
#                     pixels_per_line: 1272, pixel_control_points: 1272)
# Coordinates:
#   * wavelength_3d  (wavelength_3d) float64 1kB 339.0 341.0 344.0 ... 717.0 719.0
# Dimensions without coordinates: number_of_bands, number_of_reflective_bands,
#                                 number_of_lines, pixels_per_line,
#                                 pixel_control_points
# Data variables: (12/32)
#     wavelength     (number_of_bands) float64 2kB ...
#     vcal_gain      (number_of_reflective_bands) float32 1kB ...
#     vcal_offset    (number_of_reflective_bands) float32 1kB ...
#     F0             (number_of_reflective_bands) float32 1kB ...
#     aw             (number_of_reflective_bands) float32 1kB ...
#     bbw            (number_of_reflective_bands) float32 1kB ...
#     ...             ...
#     l2_flags       (number_of_lines, pixels_per_line) int32 9MB ...
#     longitude      (number_of_lines, pixel_control_points) float32 9MB ...
#     latitude       (number_of_lines, pixel_control_points) float32 9MB ...
#     cntl_pt_cols   (pixel_control_points) float64 10kB ...
#     cntl_pt_rows   (number_of_lines) float64 14kB ...
#     tilt           (number_of_lines) float32 7kB ...
# Attributes: (12/45)
#     title:                             OCI Level-2 Data
#     product_name:                      PACE_OCI.20240413T175656.L2.OC_AOP.V1_...
#     processing_version:                V1.0.0
#     history:                           l2gen par=/data5/sdpsoper/vdc/vpu4/wor...
#     instrument:                        OCI
#     platform:                          PACE
#     ...                                ...
#     geospatial_lon_max:                -93.55327
#     geospatial_lon_min:                -66.257095
#     startDirection:                    Ascending
#     endDirection:                      Ascending
#     day_night_flag:                    Day
#     earth_sun_distance_correction:     0.9942150712013245

# %%
ds.Rrs
# Out:
# <xarray.DataArray 'Rrs' (number_of_lines: 1710, pixels_per_line: 1272,
#                          wavelength_3d: 184)> Size: 2GB
# [400222080 values with dtype=float32]
# Coordinates:
#   * wavelength_3d  (wavelength_3d) float64 1kB 339.0 341.0 344.0 ... 717.0 719.0
# Dimensions without coordinates: number_of_lines, pixels_per_line
# Attributes:
#     long_name:      Remote sensing reflectance
#     units:          sr^-1
#     standard_name:  surface_ratio_of_upwelling_radiance_emerging_from_sea_wat...
#     valid_min:      -30000
#     valid_max:      25000

# %% [markdown]
# # Coordinates

# %%
ds = ds.set_coords(("longitude", "latitude"))

# %%
ds
# Out:
# <xarray.Dataset> Size: 3GB
# Dimensions:        (number_of_bands: 286, number_of_reflective_bands: 286,
#                     wavelength_3d: 184, number_of_lines: 1710,
#                     pixels_per_line: 1272, pixel_control_points: 1272)
# Coordinates:
#   * wavelength_3d  (wavelength_3d) float64 1kB 339.0 341.0 344.0 ... 717.0 719.0
#     longitude      (number_of_lines, pixel_control_points) float32 9MB ...
#     latitude       (number_of_lines, pixel_control_points) float32 9MB ...
# Dimensions without coordinates: number_of_bands, number_of_reflective_bands,
#                                 number_of_lines, pixels_per_line,
#                                 pixel_control_points
# Data variables: (12/30)
#     wavelength     (number_of_bands) float64 2kB ...
#     vcal_gain      (number_of_reflective_bands) float32 1kB ...
#     vcal_offset    (number_of_reflective_bands) float32 1kB ...
#     F0             (number_of_reflective_bands) float32 1kB ...
#     aw             (number_of_reflective_bands) float32 1kB ...
#     bbw            (number_of_reflective_bands) float32 1kB ...
#     ...             ...
#     angstrom       (number_of_lines, pixels_per_line) float32 9MB ...
#     avw            (number_of_lines, pixels_per_line) float32 9MB ...
#     l2_flags       (number_of_lines, pixels_per_line) int32 9MB ...
#     cntl_pt_cols   (pixel_control_points) float64 10kB ...
#     cntl_pt_rows   (number_of_lines) float64 14kB ...
#     tilt           (number_of_lines) float32 7kB ...
# Attributes: (12/45)
#     title:                             OCI Level-2 Data
#     product_name:                      PACE_OCI.20240413T175656.L2.OC_AOP.V1_...
#     processing_version:                V1.0.0
#     history:                           l2gen par=/data5/sdpsoper/vdc/vpu4/wor...
#     instrument:                        OCI
#     platform:                          PACE
#     ...                                ...
#     geospatial_lon_max:                -93.55327
#     geospatial_lon_min:                -66.257095
#     startDirection:                    Ascending
#     endDirection:                      Ascending
#     day_night_flag:                    Day
#     earth_sun_distance_correction:     0.9942150712013245
